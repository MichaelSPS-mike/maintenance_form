# %%
S2_KEYS = {
    's2_equipment_id':      ('equipment_id',       ''),
    's2_location_id':       ('location_id',        ''),
    's2_jenis_tindakan':    ('jenis_tindakan',      ''),
    's2_deskripsi_tindakan':('deskripsi_tindakan',  ''),
    's2_alasan_kegagalan':  ('alasan_kegagalan',    ''),
    's2_deskripsi_alasan':  ('deskripsi_alasan',    ''),
    's2_jenis_maintenance': ('jenis_maintenance',   ''),
    's2_mesin_mati':        ('mesin_mati',          ''),
    's2_loss_kapasitas':    ('loss_kapasitas',       None),
    's2_lama_loss_time':    ('lama_loss_time',       None),
    's2_beres':             ('beres',               ''),
    's2_durasi_solusi':     ('durasi_solusi',        ''),
    'area_select':          ('area',                ''),
    'sub_area_select':      ('sub_area',            ''),
    'bagian_select':        ('bagian',              ''),
    'sub_bagian_select':    ('sub_bagian',          ''),
}
step2_predraft = {k: (k) for k in S2_KEYS}

# %%
step2_predraft
# Out:
# {'s2_equipment_id': 's2_equipment_id',
#  's2_location_id': 's2_location_id',
#  's2_jenis_tindakan': 's2_jenis_tindakan',
#  's2_deskripsi_tindakan': 's2_deskripsi_tindakan',
#  's2_alasan_kegagalan': 's2_alasan_kegagalan',
#  's2_deskripsi_alasan': 's2_deskripsi_alasan',
#  's2_jenis_maintenance': 's2_jenis_maintenance',
#  's2_mesin_mati': 's2_mesin_mati',
#  's2_loss_kapasitas': 's2_loss_kapasitas',
#  's2_lama_loss_time': 's2_lama_loss_time',
#  's2_beres': 's2_beres',
#  's2_durasi_solusi': 's2_durasi_solusi',
#  'area_select': 'area_select',
#  'sub_area_select': 'sub_area_select',
#  'bagian_select': 'bagian_select',
#  'sub_bagian_select': 'sub_bagian_select'}
